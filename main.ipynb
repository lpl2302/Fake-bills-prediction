# %%
# Import needed packages

# %%
# !pip install scikit-learn
# !pip install matplotlib
# !pip install pandas 
# !pip install numpy 
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Data

# %%
path= "/Users/linhlp/Downloads/tft project/fake bills/fake_bills.csv"

# %%
data = pd.read_csv(path) #read data in

# %%
data.head() #view the data
# Out:
#   is_genuine;diagonal;height_left;height_right;margin_low;margin_up;length
# 0         True;171.81;104.86;104.95;4.52;2.89;112.83
# 1         True;171.46;103.36;103.66;3.77;2.99;113.09
# 2           True;172.69;104.48;103.5;4.4;2.94;113.16
# 3         True;171.36;103.91;103.94;3.62;3.01;113.51
# 4         True;171.73;104.28;103.46;4.04;3.48;112.54

# %%
data_missing = data.isnull().sum()
data_missing
# Out:
# is_genuine;diagonal;height_left;height_right;margin_low;margin_up;length    0
# dtype: int64

# %%
data_split = df['is_genuine;diagonal;height_left;height_right;margin_low;margin_up;length'].str.split(';', expand=True)
data_split.columns = ['is_genuine', 'diagonal', 'height_left', 'height_right', 'margin_low', 'margin_up', 'length']
for col in data_split.columns:
    try:
        data_split[col] = pd.to_numeric(data_split[col])
    except ValueError:
        pass
data_split['is_genuine'] = data_split['is_genuine'].replace({'True': 1, 'False': 0}).astype(int)
missing_values_split = data_split.isnull().sum()
data_split.head(), missing_values_split
# Out:
# /var/folders/c6/sbdnrpf54pl873qgqwv_yv8w0000gn/T/ipykernel_25477/1721158677.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_split['is_genuine'] = data_split['is_genuine'].replace({'True': 1, 'False': 0}).astype(int)
# (   is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
#  0           1    171.81       104.86        104.95        4.52       2.89
#  1           1    171.46       103.36        103.66        3.77       2.99
#  2           1    172.69       104.48        103.50        4.40       2.94
#  3           1    171.36       103.91        103.94        3.62       3.01
#  4           1    171.73       104.28        103.46        4.04       3.48
#
#     length
#  0  112.83
#  1  113.09
#  2  113.16
#  3  113.51
# ...

# %%
cdf = data_split[['diagonal','height_left','height_right','margin_low','margin_up','length']]
cdf.head(9)
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length
# 0    171.81       104.86        104.95        4.52       2.89  112.83
# 1    171.46       103.36        103.66        3.77       2.99  113.09
# 2    172.69       104.48        103.50        4.40       2.94  113.16
# 3    171.36       103.91        103.94        3.62       3.01  113.51
# 4    171.73       104.28        103.46        4.04       3.48  112.54
# 5    172.17       103.74        104.08        4.42       2.95  112.81
# 6    172.34       104.18        103.85        4.58       3.26  112.81
# 7    171.88       103.76        104.08        3.98       2.92  113.08
# 8    172.47       103.92        103.67        4.00       3.25  112.85

# %%
msk = np.random.rand(len(data_split)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
data_cleaned = data_split.dropna(subset=['margin_low'])

x = np.asanyarray(data_cleaned[['diagonal', 'height_left', 'height_right', 'margin_up', 'length']])
y = np.asanyarray(data_cleaned[['margin_low']])

X_train, X_test, y_train, y_test = train_test_split(x[~np.isnan(y).flatten()], y[~np.isnan(y).flatten()], test_size=0.2, random_state=0)
regr = linear_model.LinearRegression()
regr.fit (x, y)
# Out:
# LinearRegression()

# %%
# Prediction

# %%
y_hat = regr.predict(X_test)

# %%
print('Coefficients:', regr.coef_)
print("Residual sum of squares: %.2f" % np.mean((y_hat - y_test) ** 2))
print('Variance score: %.2f' % regr.score(X_test, y_test))
# Out:
# Coefficients: [[-0.11105978  0.18412242  0.25713805  0.2561879  -0.40910293]]
# Residual sum of squares: 0.25
# Variance score: 0.48
